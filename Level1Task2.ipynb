# %% [markdown]
# Task2:Descriptive Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
dataset = pd.read_csv("Dataset.csv")
dataset.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Calculate basic statistical measures (mean,median, standard deviation, etc.) for numerical columns.

# %%
dataset.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# Explore the distribution of categorical variables like "Country Code", "City" and "Cuisines".

# %%
import seaborn as sns;sns.set(color_codes=True)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="Country Code",data=dataset,palette='cividis')
plt.title('Distribution of Restaurant by Country Code')
plt.xlabel('Country Code')
plt.ylabel('No. of Restaurant')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20556\1569791662.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Country Code",data=dataset,palette='cividis')

# %% [markdown]
# Identify the top cuisines and cities with the highest number of restaurants.

# %%
top_countries=dataset=dataset['Country Code'].value_counts().head()
print("Top 5 countries with the highest no. of Restarant : ")
print(top_countries)
# Out:
# Top 5 countries with the highest no. of Restarant :
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x="City",data=dataset, order=dataset["City"].value_counts().head(20).index,palette='Set2')
plt.title('Distribution of Restaurant by City:')
plt.xlabel('City')
plt.ylabel('No. of Restaurant')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20556\2952665964.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="City",data=dataset, order=dataset["City"].value_counts().head(20).index,palette='Set2')
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65533 (\N{REPLACEMENT CHARACTER}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14, 6))
cuisines_count=dataset['Cuisines'].value_counts()
cuisines_count.head(20).plot(kind="bar",color=sns.color_palette("Set2"))
plt.title('Top 20 Cuisines with the highest no. of Restarant :')
plt.xlabel('Cuisines')
plt.ylabel('No. of Restaurant')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
top_cities=dataset["City"].value_counts().head(10)
print("Top 10 cities with the highest no. of Restarant : ")
print(top_cities)
# Out:
# Top 10 cities with the highest no. of Restarant :
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Lucknow           21
# Ahmedabad         21
# Amritsar          21
# Guwahati          21
# Name: count, dtype: int64

# %%
top_cusines=cuisines_count.head(10)
print("Top 10 cusines with the highest no. of Restarant : ")
print(top_cusines)
# Out:
# Top 10 cusines with the highest no. of Restarant :
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64
