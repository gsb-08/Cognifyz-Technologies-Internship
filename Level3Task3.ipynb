# %% [markdown]
# Task: Data Visualization
#
# Create visualizations to represent the distribution
# of ratings using different charts (histogram, bar
# plot, etc.).
#
# Compare the average ratings of different cuisines
# or cities using appropriate visualizations.
#
# Visualize the relationship between various
# features and the target variable to gain insights.

# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the dataset
df = pd.read_csv('Dataset.csv')

# Set style
sns.set_theme()

# 1. Distribution of Aggregate Ratings
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Aggregate rating', bins=20)
plt.title('Distribution of Restaurant Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

print("Done with first visualization")
# Out:
# Done with first visualization

# %%
plt.figure(figsize=(12, 6))
city_ratings = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=city_ratings.index, y=city_ratings.values)
plt.title('Average Rating by City (Top 10)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Average Rating by Cuisine (Top 10 cuisines)
# First, split the cuisines and get unique ones
cuisines = df['Cuisines'].str.split(', ', expand=True).stack()
cuisine_ratings = df.assign(Cuisine=df['Cuisines'].str.split(', ').str[0])
cuisine_avg = cuisine_ratings.groupby('Cuisine')['Aggregate rating'].agg(['mean', 'count'])
cuisine_avg = cuisine_avg[cuisine_avg['count'] > 20].sort_values('mean', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=cuisine_avg.index, y=cuisine_avg['mean'])
plt.title('Average Rating by Cuisine (Top 10, min 20 restaurants)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 3. Relationship between Price Range and Ratings
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Price range', y='Aggregate rating')
plt.title('Price Range vs Ratings')
plt.xlabel('Price Range')
plt.ylabel('Rating')
plt.show()

print("Done with price range visualization")
# Out:
# Done with price range visualization
